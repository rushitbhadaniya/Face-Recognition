# %%
pip install face_recognition
# Out:
# ...
#      |████████████████████████████████| 100.2MB 103kB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566172 sha256=4c47f2a1d5f96652d5510f2f3a0b4631808bd76bad61eab780b820744e4b5f19
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# ...

# %%
import PIL.Image
import PIL.ImageDraw
import face_recognition

# %%
#load the jpg file into a numpy array
image=face_recognition.load_image_file("rushit.jpeg")

# %%
#find all facial feature in all the faces in the image
face_landmarks_list = face_recognition.face_landmarks(image)

number_of_faces=len(face_landmarks_list)
print("I found {} face(s) in this photograph.".format(number_of_faces))
# Out:
# I found 1 face(s) in this photograph.

# %%
# Load the image into a Python Image Library object so that we can draw on top of it and display it
pil_image = PIL.Image.fromarray(image)

# %%
#create PIL drawing object to be draw lines later
draw= PIL.ImageDraw.Draw(pil_image)

#Loop over each face

for face_landmarks in face_landmarks_list:

  # loop over each facial feature (eye, nose , mouth ,lips,etc)
  for name,list_of_points in face_landmarks.items():
    # Print the locaton of each facial feature 
    print("The {} in this face has the following points: {}".format(name,list_of_points))
    draw.line(list_of_points,fill="red",width=5)
pil_image
# Out:
# The chin in this face has the following points: [(962, 962), (966, 1024), (975, 1086), (989, 1147), (1008, 1208), (1041, 1263), (1087, 1311), (1146, 1344), (1217, 1352), (1288, 1342), (1348, 1309), (1399, 1264), (1439, 1208), (1461, 1147), (1476, 1084), (1484, 1019), (1487, 954)]
# The left_eyebrow in this face has the following points: [(1001, 923), (1031, 883), (1082, 867), (1135, 874), (1185, 893)]
# The right_eyebrow in this face has the following points: [(1244, 893), (1291, 873), (1344, 869), (1396, 883), (1429, 924)]
# The nose_bridge in this face has the following points: [(1215, 932), (1216, 972), (1217, 1010), (1219, 1052)]
# The nose_tip in this face has the following points: [(1164, 1088), (1191, 1093), (1220, 1100), (1247, 1093), (1275, 1086)]
# The left_eye in this face has the following points: [(1057, 947), (1085, 930), (1118, 928), (1149, 946), (1116, 950), (1084, 952)]
# ...
